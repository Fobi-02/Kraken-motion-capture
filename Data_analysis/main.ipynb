# %%
import matplotlib.pyplot as plt
from functions.read_csv import read_csv
from functions.plot_markers import plot_markers
from functions.plot_markers_slide import plot_markers_slider

# loading the first file data
csv_file = "../Data/F-30_001.csv"
df = read_csv(csv_file)

# %%
# Plotting the markers in a wanted frame
frame = 100
#plot_markers(df, frame)

# plotting the markers with a slider to choose the frame
plot_markers_slider(df, step=100)

# %%
plt.figure(figsize=(10, 5))
plt.plot(df["Time"],df["p_1534_Z"])
plt.xlabel("Time [s]")
plt.ylabel("X [mm]")
plt.grid()
plt.show()
